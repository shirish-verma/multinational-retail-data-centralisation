# %%
import json
import requests
import numpy as np
import pandas as pd
from data_cleaning import DataCleaning
from data_extraction import DataExtractor
from database_utils import DatabaseConnector

# %%
raw_user_df = DataExtractor.read_rds_table('legacy_users')
clean_user_df = DataCleaning.clean_user_data(raw_user_df)

# %%
raw_user_df['user_uuid', ].head(10)
# Out:
# index
# 0    93caf182-e4e9-4c6e-bebb-60a1a9dcf9b8
# 1    8fe96c3a-d62d-4eb5-b313-cf12d9126a49
# 2    fc461df4-b919-48b2-909e-55c95a03fe6b
# 3    6104719f-ef14-4b09-bf04-fb0c4620acb0
# 4    9523a6d3-b2dd-4670-a51a-36aebc89f579
# 5    53d21f46-1fa4-452f-a023-26aee2aae4d6
# 6    e2066a2c-8cd3-46ad-b2ea-e2445d5d9335
# 7    bd690c60-c952-40c0-82df-0f8b6797b562
# 8    02de2416-4baf-42ad-bae6-d716eca0fc3f
# 9    caffe463-4918-4f45-a37d-856dc0f15884
# Name: user_uuid, dtype: object

# %%
raw_orders_df = DataExtractor.read_rds_table('orders_table')
clean_orders_df = DataCleaning.clean_orders_data(raw_orders_df)

# %%
clean_orders_df[['date_uuid', 'user_uuid']].head(20)
# Out:
#                                   date_uuid  \
# index
# 0      9476f17e-5d6a-4117-874d-9cdb38ca1fa6
# 1      0423a395-a04d-4e4a-bd0f-d237cbd5a295
# 2      65187294-bb16-4519-adc0-787bbe423970
# 3      579e21f7-13cb-436b-83ad-33687a4eb337
# 4      00ab86c3-2039-4674-b9c1-adbcbbf525bd
# 5      c3a1df8f-6918-4795-9f8a-6869b2cda9cf
# 6      ac94c06e-b5ba-4794-bbf3-3ea9dc0e6b6c
# 7      27a59013-6ecf-4f3d-86f8-8e972a8f346c
# 8      38ebd7b6-b1d4-462e-bfd7-265e3674ef3f
# 9      e764e21c-f9ce-4e0a-8c01-4218e92e424c
# 10     938a8972-784f-4f65-84bc-5fe51051ccbe
# 11     2e78a288-31c6-4a2a-8aea-cb93ad389aaa
# 12     0e1e7e2b-ba00-4c47-9daf-d8f527086f76
# 13     07248e1a-da56-4e94-8510-a9a47f80e0e2
# 14     734714b8-f418-4c3b-bffd-9621beb0ea3b
# 15     b6831c7f-e8f2-42e8-b05c-94f3921fdee2
# 16     f84d4161-6aad-4730-9c90-391ca8db44af
# 17     3db24e27-18e7-457e-9bb7-2a1ae81c8e13
# 18     f0bf8f8f-4a5e-4ab3-8ea8-6486205fc0b9
# 19     41ade3a2-74b0-4098-9b0e-d3fe33a9a1a7
#
#                                   user_uuid
# index
# 0      93caf182-e4e9-4c6e-bebb-60a1a9dcf9b8
# 1      8fe96c3a-d62d-4eb5-b313-cf12d9126a49
# 2      fc461df4-b919-48b2-909e-55c95a03fe6b
# 3      6104719f-ef14-4b09-bf04-fb0c4620acb0
# 4      9523a6d3-b2dd-4670-a51a-36aebc89f579
# 5      53d21f46-1fa4-452f-a023-26aee2aae4d6
# 6      e2066a2c-8cd3-46ad-b2ea-e2445d5d9335
# 7      bd690c60-c952-40c0-82df-0f8b6797b562
# 8      02de2416-4baf-42ad-bae6-d716eca0fc3f
# 9      caffe463-4918-4f45-a37d-856dc0f15884
# 10     884fa18d-cc40-4e75-87c6-0786ab29933a
# 11     bf86d13b-882b-485e-addd-0c4e9a39a96c
# 12     52717e6a-955c-4c16-8f25-9e6a71ba3f60
# 13     196c8554-5df5-4519-973c-e05c0781cf52
# 14     21be4057-b932-41c4-96c0-0c9ab2c48d6c
# 15     c6eeaf38-40d1-490d-be78-0cadf870fdc3
# 16     7c8dc654-3994-40b1-a4a2-e55dc7081fe0
# 17     3ca7e4af-c9af-4ae8-bf68-cf9e9ddf745c
# 18     4dff00da-ffb7-4cd4-accf-805738e630dd
# 19     649b54e4-011e-43e1-b0f7-e90f355f806e

# %%
raw_products_df = DataExtractor.extract_from_s3('s3://data-handling-public/products.csv')
interim_products_df = DataCleaning.clean_products_data(raw_products_df)
clean_products_df = DataCleaning.convert_product_weights(interim_products_df)

# %%
raw_products_df['weight'].sort_values()
# Out:
# 160         0.01kg
# 186         0.03kg
# 184         0.06kg
# 211        0.072kg
# 297        0.087kg
#            ...
# 751     9GO9NZ5JTL
# 575            9kg
# 853            9kg
# 1400    MX180RYSHX
# 1133    Z8ZTDGUZVU
# Name: weight, Length: 1849, dtype: object

# %%
number_of_stores = DataExtractor.list_number_of_stores('https://aqj7u5id95.execute-api.eu-west-1.amazonaws.com/prod/number_stores')
raw_stores_df = DataExtractor.retrieve_stores_data(number_of_stores, 'https://aqj7u5id95.execute-api.eu-west-1.amazonaws.com/prod/store_details/{store_number}')
clean_stores_df = DataCleaning.clean_store_data(raw_stores_df)

# %%
de_store_codes = raw_stores_df['store_code'].loc[raw_stores_df['country_code'] == 'DE']

# %%
raw_orders_df[raw_orders_df['store_code'].isin(de_store_codes)]
# Out:
#                                    date_uuid  \
# index
# 7       27a59013-6ecf-4f3d-86f8-8e972a8f346c
# 16      f84d4161-6aad-4730-9c90-391ca8db44af
# 17      3db24e27-18e7-457e-9bb7-2a1ae81c8e13
# 23      07d20be3-eca5-49a0-8e04-ab64ba757fad
# 24      0b7145a1-cc1e-478c-bc49-44c625f4eb06
# ...                                      ...
# 66257   ffcaae77-a983-41db-9ea1-65abb4036bc1
# 67926   c9c2a9c7-3ef3-4c8b-8eab-01c5e531039e
# 90560   0ee2328b-6d46-4c6a-9302-d56b9b0162cc
# 95080   d950d99a-f49f-4a5b-b81d-e4d6570c4fac
# 109636  bbf9ba49-face-43e3-b732-d5089117e07e
#
#                                    user_uuid          card_number  \
# index
# 7       bd690c60-c952-40c0-82df-0f8b6797b562     2321541881278150
# 16      7c8dc654-3994-40b1-a4a2-e55dc7081fe0  4537509987455280000
# 17      3ca7e4af-c9af-4ae8-bf68-cf9e9ddf745c     6011881097126120
# 23      fb47ef8a-7caf-4f43-b227-8fd0354caf85  4305628477334070000
# 24      04c29a16-f3b3-4ca8-8971-e67d7863985d     6011112632675670
# ...                                      ...                  ...
# 66257   45447a05-97cf-42ac-b839-5f1416945e41     4971858637664481
# 67926   4cac12fb-b8f2-46c5-874a-1df4f847c6a2     4971858637664481
# 90560   3aa38cc6-5bd9-4081-9809-d53dc745224d  4252720361802860591
# 95080   b33e2201-48d6-410e-a6c5-dedc039a8c59         575421945446
# 109636  0ab4dbd9-cdbc-434b-8fe4-7c80eefe1c06         575421945446
#
#          store_code product_code  product_quantity
# index
# 7       OB-FDC2CF69  q8-5387483Z                 3
# 16      HA-B6953307  P1-5362711n                 1
# 17      CH-7C155EA7  v7-6917295v                 3
# 23      LA-347073D1  w9-8766704u                 1
# 24      HE-A49D28DF  f1-4722530k                 5
# ...             ...          ...               ...
# 66257   HA-FC4E6AFF  c7-6364718G                 1
# 67926   VE-1050754E  k9-3755441k                 5
# 90560   SI-ECD52CD9  T2-5997834g                 9
# 95080   SC-8724E112  l8-5672498Q                 2
# 109636  BA-B4AED588  a1-6864441W                 7
#
# [29984 rows x 6 columns]
